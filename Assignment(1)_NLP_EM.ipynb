# %%
#sentimental analysis on the Elon-musk tweets (Exlon-musk.csv)

import pandas as pd

# %%
EM=pd.read_csv("C:/Users/1234/Downloads/Elon_musk.csv",encoding='latin-1')

# %%
EM.head()
# Out:
#    Unnamed: 0                                               Text
# 0           1                             @kunalb11 Im an alien
# 1           2  @ID_AA_Carmack Ray tracing on Cyberpunk with H...
# 2           3                @joerogan @Spotify Great interview!
# 3           4                    @gtera27 Doge is underestimated
# 4           5  @teslacn Congratulations Tesla China for amazi...

# %%
EM[4:5]
# Out:
#    Unnamed: 0                                               Text
# 4           5  @teslacn Congratulations Tesla China for amazi...

# %%
PW=pd.read_csv("C:/Users/1234/Downloads/positive-words.txt",error_bad_lines=False)
# Out:
# b'Skipping line 10: expected 1 fields, saw 2\nSkipping line 14: expected 1 fields, saw 5\nSkipping line 15: expected 1 fields, saw 3\nSkipping line 16: expected 1 fields, saw 2\nSkipping line 18: expected 1 fields, saw 3\nSkipping line 19: expected 1 fields, saw 3\nSkipping line 27: expected 1 fields, saw 3\nSkipping line 28: expected 1 fields, saw 2\n'

# %% [markdown]
# ##### PW.head(36)

# %%
Positive_word=PW[25:]
Positive_word
# Out:
#      ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# 25                                                   a+
# 26                                               abound
# 27                                              abounds
# 28                                            abundance
# 29                                             abundant
# ...                                                 ...
# 2026                                           youthful
# 2027                                               zeal
# 2028                                             zenith
# 2029                                               zest
# 2030                                              zippy
#
# [2006 rows x 1 columns]

# %%
Positive_word.rename(columns = {";;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;":"Positive_word"},inplace=True)
# Out:
# C:\Users\1234\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#Positive_word.reset_index()
Positive_word.reset_index(drop=True)
# Out:
#      Positive_word
# 0               a+
# 1           abound
# 2          abounds
# 3        abundance
# 4         abundant
# ...            ...
# 2001      youthful
# 2002          zeal
# 2003        zenith
# 2004          zest
# 2005         zippy
#
# [2006 rows x 1 columns]

# %%
NW=pd.read_csv("C:/Users/1234/Downloads/negative-words.txt",engine="python",error_bad_lines=False)
# Out:
# Skipping line 11: Expected 1 fields in line 11, saw 2
# Skipping line 15: Expected 1 fields in line 15, saw 5
# Skipping line 16: Expected 1 fields in line 16, saw 3
# Skipping line 17: Expected 1 fields in line 17, saw 2
# Skipping line 19: Expected 1 fields in line 19, saw 3
# Skipping line 20: Expected 1 fields in line 20, saw 3
# Skipping line 28: Expected 1 fields in line 28, saw 3
# Skipping line 29: Expected 1 fields in line 29, saw 2

# %%
NW.head(36)
# Out:
#    ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# 0                                                  ;
# 1                         ; Opinion Lexicon: Negative
# 2                                                   ;
# 3   ; This file contains a list of NEGATIVE opinio...
# 4                                                   ;
# 5   ; This file and the papers can all be download...
# 6   ;    http://www.cs.uic.edu/~liub/FBS/sentiment...
# 7                                                   ;
# 8                                                   ;
# 9   ;   Minqing Hu and Bing Liu. "Mining and Summa...
# 10  ;       Proceedings of the ACM SIGKDD Internat...
# 11  ;       and Comparing Opinions on the Web." Pr...
# 12                                                  ;
# 13                                          ; Notes:
# 14  ;    1. The appearance of an opinion word in a...
# 15  ;       mean that the sentence expresses a pos...
# ...

# %%
Negative_word=NW[25:]
Negative_word
# Out:
#      ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# 25                                              2-faced
# 26                                              2-faces
# 27                                             abnormal
# 28                                              abolish
# 29                                           abominable
# ...                                                 ...
# 4803                                               zaps
# 4804                                             zealot
# 4805                                            zealous
# 4806                                          zealously
# 4807                                             zombie
#
# [4783 rows x 1 columns]

# %%
Negative_word.rename(columns = {";;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;":"Negative_word"},inplace=True)
# Out:
# C:\Users\1234\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
Negative_word
# Out:
#      Negative_word
# 25         2-faced
# 26         2-faces
# 27        abnormal
# 28         abolish
# 29      abominable
# ...            ...
# 4803          zaps
# 4804        zealot
# 4805       zealous
# 4806     zealously
# 4807        zombie
#
# [4783 rows x 1 columns]

# %%
Negative_word.reset_index(drop=True)
# Out:
#      Negative_word
# 0          2-faced
# 1          2-faces
# 2         abnormal
# 3          abolish
# 4       abominable
# ...            ...
# 4778          zaps
# 4779        zealot
# 4780       zealous
# 4781     zealously
# 4782        zombie
#
# [4783 rows x 1 columns]

# %%
EM = [Text.strip() for Text in EM.Text] # remove both the leading and the trailing characters
EM = [Text for Text in EM if Text] # removes empty strings, because they are considered in Python as False
EM[0:10]
# Out:
# ['@kunalb11 I\x92m an alien',
#  '@ID_AA_Carmack Ray tracing on Cyberpunk with HDR is next-level. Have you tried it?',
#  '@joerogan @Spotify Great interview!',
#  '@gtera27 Doge is underestimated',
#  '@teslacn Congratulations Tesla China for amazing execution last year. Now on to the next for even more!!',
#  'Happy New Year of the Ox! https://t.co/9WFKMYu2oj',
#  'Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all. https://t.co/zGxJFDzzrM',
#  '@OwenSparks_ @flcnhvy @anonyx10 Haha thanks :)',
#  '@flcnhvy @anonyx10 Indeed! Tweets definitely do not represent real-world time allocation.',
#  'The most entertaining outcome is the most likely']

# %%
#sentiment analysis
afinn = pd.read_csv("C:/Users/1234/Downloads/Afinn.csv", sep=',', encoding='latin-1')
afinn
# Out:
#            word  value
# 0       abandon     -2
# 1     abandoned     -2
# 2      abandons     -2
# 3      abducted     -2
# 4     abduction     -2
# ...         ...    ...
# 2472      yucky     -2
# 2473      yummy      3
# 2474     zealot     -2
# 2475    zealots     -2
# 2476    zealous      2
#
# [2477 rows x 2 columns]

# %%
afinn.shape
# Out:
# (2477, 2)

# %%
# Now we check sentiment score for sentences(reviews)
from nltk import tokenize
sentences = tokenize.sent_tokenize(' '.join(EM))
sentences[5:15]
# Out:
# ['Happy New Year of the Ox!',
#  'https://t.co/9WFKMYu2oj Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all.',
#  'https://t.co/zGxJFDzzrM @OwenSparks_ @flcnhvy @anonyx10 Haha thanks :) @flcnhvy @anonyx10 Indeed!',
#  'Tweets definitely do not represent real-world time allocation.',
# ...

# %%
type(sentences)
# Out:
# list

# %%
type(EM)
# Out:
# list

# %%
sent_df = pd.DataFrame(sentences, columns=['sentence'])
sent_df
# Out:
#                                               sentence
# 0    @kunalb11 Im an alien @ID_AA_Carmack Ray trac...
# 1                                   Have you tried it?
# 2                  @joerogan @Spotify Great interview!
# 3    @gtera27 Doge is underestimated @teslacn Congr...
# 4                   Now on to the next for even more!!
# ..                                                 ...
# 919  @kenyanwalstreet Not actually a payout, just a...
# 920  It may never pay out, as the stock cant b
#  ht...
# 921                                    Details Aug 28.
# 922  AI symbiosis while u wait @vistacruiser7 @flcn...
# 923  @TeslaGong @PPathole Samwise Gamgee @PPathole ...
#
# [924 rows x 1 columns]

# %%
affinity_scores = afinn.set_index('word')['value'].to_dict()
affinity_scores
# Out:
# {'abandon': -2,
#  'abandoned': -2,
#  'abandons': -2,
#  'abducted': -2,
#  'abduction': -2,
#  'abductions': -2,
#  'abhor': -3,
#  'abhorred': -3,
#  'abhorrent': -3,
#  'abhors': -3,
#  'abilities': 2,
#  'ability': 2,
#  'aboard': 1,
#  'absentee': -1,
#  'absentees': -1,
#  'absolve': 2,
#  'absolved': 2,
#  'absolves': 2,
#  'absolving': 2,
#  'absorbed': 1,
#  'abuse': -3,
#  'abused': -3,
#  'abuses': -3,
#  'abusive': -3,
#  'accept': 1,
#  'accepted': 1,
#  'accepting': 1,
#  'accepts': 1,
#  'accident': -2,
#  'accidental': -2,
#  'accidentally': -2,
#  'accidents': -2,
#  'accomplish': 2,
#  'accomplished': 2,
#  'accomplishes': 2,
#  'accusation': -2,
#  'accusations': -2,
#  'accuse': -2,
#  'accused': -2,
#  'accuses': -2,
#  'accusing': -2,
#  'ache': -2,
#  'achievable': 1,
#  'aching': -2,
#  'acquit': 2,
#  'acquits': 2,
#  'acquitted': 2,
#  'acquitting': 2,
#  'acrimonious': -3,
#  'active': 1,
#  'adequate': 1,
#  'admire': 3,
#  'admired': 3,
#  'admires': 3,
# ...

# %%
#custom function: score each word in a sentence in lemmatised form
#but calculate score for whole original sentences
#!python -m spacy download en
import spacy
nlp = spacy.load('en_core_web_sm')

sentiment_laxicon = affinity_scores

# %%
sentiment_laxicon
# Out:
# {'abandon': -2,
#  'abandoned': -2,
#  'abandons': -2,
#  'abducted': -2,
#  'abduction': -2,
#  'abductions': -2,
#  'abhor': -3,
#  'abhorred': -3,
#  'abhorrent': -3,
#  'abhors': -3,
#  'abilities': 2,
#  'ability': 2,
#  'aboard': 1,
#  'absentee': -1,
#  'absentees': -1,
#  'absolve': 2,
#  'absolved': 2,
#  'absolves': 2,
#  'absolving': 2,
#  'absorbed': 1,
#  'abuse': -3,
#  'abused': -3,
#  'abuses': -3,
#  'abusive': -3,
#  'accept': 1,
#  'accepted': 1,
#  'accepting': 1,
#  'accepts': 1,
#  'accident': -2,
#  'accidental': -2,
#  'accidentally': -2,
#  'accidents': -2,
#  'accomplish': 2,
#  'accomplished': 2,
#  'accomplishes': 2,
#  'accusation': -2,
#  'accusations': -2,
#  'accuse': -2,
#  'accused': -2,
#  'accuses': -2,
#  'accusing': -2,
#  'ache': -2,
#  'achievable': 1,
#  'aching': -2,
#  'acquit': 2,
#  'acquits': 2,
#  'acquitted': 2,
#  'acquitting': 2,
#  'acrimonious': -3,
#  'active': 1,
#  'adequate': 1,
#  'admire': 3,
#  'admired': 3,
#  'admires': 3,
# ...

# %%
def calculate_sentiment (text: str=None):
    sent_score=0
    if text:
        sentence=nlp(text)
        for word in sentence:
            sent_score += sentiment_laxicon.get(word.lemma_, 0)
    return sent_score

# %%
sent_df['sentiment_value'] = sent_df['sentence'].apply(calculate_sentiment)
sent_df
# Out:
#                                               sentence  sentiment_value
# 0    @kunalb11 Im an alien @ID_AA_Carmack Ray trac...                0
# 1                                   Have you tried it?                0
# 2                  @joerogan @Spotify Great interview!                3
# 3    @gtera27 Doge is underestimated @teslacn Congr...                3
# 4                   Now on to the next for even more!!                0
# ..                                                 ...              ...
# 919  @kenyanwalstreet Not actually a payout, just a...                0
# 920  It may never pay out, as the stock cant b
#  ht...               -4
# 921                                    Details Aug 28.                0
# 922  AI symbiosis while u wait @vistacruiser7 @flcn...               -2
# 923  @TeslaGong @PPathole Samwise Gamgee @PPathole ...                0
#
# [924 rows x 2 columns]

# %%
# how many words are in the sentence
sent_df['word_count'] = sent_df['sentence'].str.split().apply(len)
sent_df['word_count']
# Out:
# 0      13
# 1       4
# 2       4
# 3      13
# 4       8
#        ..
# 919    11
# 920    31
# 921     3
# 922    47
# 923    15
# Name: word_count, Length: 924, dtype: int64

# %%
sent_df
# Out:
#                                               sentence  sentiment_value  \
# 0    @kunalb11 Im an alien @ID_AA_Carmack Ray trac...                0
# 1                                   Have you tried it?                0
# 2                  @joerogan @Spotify Great interview!                3
# 3    @gtera27 Doge is underestimated @teslacn Congr...                3
# 4                   Now on to the next for even more!!                0
# ..                                                 ...              ...
# 919  @kenyanwalstreet Not actually a payout, just a...                0
# 920  It may never pay out, as the stock cant b
#  ht...               -4
# 921                                    Details Aug 28.                0
# 922  AI symbiosis while u wait @vistacruiser7 @flcn...               -2
# 923  @TeslaGong @PPathole Samwise Gamgee @PPathole ...                0
#
#      word_count
# 0            13
# 1             4
# 2             4
# 3            13
# ...

# %%
sent_df.sort_values(by='sentiment_value').tail(10)
# Out:
#                                               sentence  sentiment_value  \
# 183  Theres some great AI out ther
#  https://t.co/v...               10
# 224  @PPathole @karpathy For a second there, I thou...               11
# 817  Might be able to
#  https://t.co/FB7e5nOq2E @Pri...               11
# 184  Also, w
#  https://t.co/IYdKttVsqk @cleantechnic...               12
# 645  Its
#  https://t.co/IxhyT6NuiC @Teslarati Tesla...               13
# 81   @teslaownersSV This is a good one @MrBeastYT I...               13
# 585  The open areas
#  https://t.co/rabjKrtQlw @Sav...               14
# 719  We just havent observed the
#  https://t.co/mez...               15
# 36   @ajtourville @Erdayastronaut @SpaceX Yes, but ...               15
# 105  @Erdayastronaut @SpaceX Was also thinking that...               16
#
#      word_count
# 183          48
# 224          69
# 817          72
# 184          98
# 645          65
# 81           38
# 585         138
# 719          72
# ...

# %%
# sentiment score of the whole review
sent_df['sentiment_value'].describe()
# Out:
# count    924.000000
# mean       1.352814
# std        2.671421
# min       -8.000000
# 25%        0.000000
# 50%        0.000000
# 75%        3.000000
# max       16.000000
# Name: sentiment_value, dtype: float64

# %%
# Sentiment score of the whole review
sent_df[sent_df['sentiment_value']<=0]
# Out:
#                                               sentence  sentiment_value  \
# 0    @kunalb11 Im an alien @ID_AA_Carmack Ray trac...                0
# 1                                   Have you tried it?                0
# 4                   Now on to the next for even more!!                0
# 6    https://t.co/9WFKMYu2oj Frodo was the underdog...               -2
# 8    Tweets definitely do not represent real-world ...                0
# ..                                                 ...              ...
# 919  @kenyanwalstreet Not actually a payout, just a...                0
# 920  It may never pay out, as the stock cant b
#  ht...               -4
# 921                                    Details Aug 28.                0
# 922  AI symbiosis while u wait @vistacruiser7 @flcn...               -2
# 923  @TeslaGong @PPathole Samwise Gamgee @PPathole ...                0
#
#      word_count
# 0            13
# 1             4
# 4             8
# 6            14
# ...

# %%
sent_df[sent_df['sentiment_value']>=10]
# Out:
#                                               sentence  sentiment_value  \
# 36   @ajtourville @Erdayastronaut @SpaceX Yes, but ...               15
# 81   @teslaownersSV This is a good one @MrBeastYT I...               13
# 105  @Erdayastronaut @SpaceX Was also thinking that...               16
# 159  @harsimranbansal @heydave7 It will most likely...               10
# 183  Theres some great AI out ther
#  https://t.co/v...               10
# 184  Also, w
#  https://t.co/IYdKttVsqk @cleantechnic...               12
# 224  @PPathole @karpathy For a second there, I thou...               11
# 585  The open areas
#  https://t.co/rabjKrtQlw @Sav...               14
# 645  Its
#  https://t.co/IxhyT6NuiC @Teslarati Tesla...               13
# 719  We just havent observed the
#  https://t.co/mez...               15
# 817  Might be able to
#  https://t.co/FB7e5nOq2E @Pri...               11
# 855  Impressive Tianwen-1 Mars rover mission launch...               10
#
#      word_count
# ...

# %%
sent_df['index']=range(0,len(sent_df))

# %%
sent_df=sent_df[['index']+['sentence']+['word_count']+['sentiment_value']]
sent_df.reset_index(drop=True)
sent_df
# Out:
#      index                                           sentence  word_count  \
# 0        0  @kunalb11 Im an alien @ID_AA_Carmack Ray trac...          13
# 1        1                                 Have you tried it?           4
# 2        2                @joerogan @Spotify Great interview!           4
# 3        3  @gtera27 Doge is underestimated @teslacn Congr...          13
# 4        4                 Now on to the next for even more!!           8
# ..     ...                                                ...         ...
# 919    919  @kenyanwalstreet Not actually a payout, just a...          11
# 920    920  It may never pay out, as the stock cant b
#  ht...          31
# 921    921                                    Details Aug 28.           3
# 922    922  AI symbiosis while u wait @vistacruiser7 @flcn...          47
# 923    923  @TeslaGong @PPathole Samwise Gamgee @PPathole ...          15
#
#      sentiment_value
# 0                  0
# 1                  0
# ...

# %%
sentiment = []
for i in range(len(sent_df)):
  c = sent_df.iloc[i]['sentiment_value']
  if c>0:
    sentiment.append("pos")
  elif c<0:
    sentiment.append("neg")
  else:
    sentiment.append("neutral")
sent_df['Sentiment']=sentiment
sent_df
# Out:
# C:\Users\1234\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#      index                                           sentence  word_count  \
# 0        0  @kunalb11 Im an alien @ID_AA_Carmack Ray trac...          13
# 1        1                                 Have you tried it?           4
# 2        2                @joerogan @Spotify Great interview!           4
# 3        3  @gtera27 Doge is underestimated @teslacn Congr...          13
# 4        4                 Now on to the next for even more!!           8
# ..     ...                                                ...         ...
# ...

# %%
sent_df['Sentiment'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(sent_df['sentiment_value'])
# Out:
# C:\Users\1234\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sentiment_value', ylabel='Density'>

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x='index', y='sentiment_value', data=sent_df)
# Out:
# <AxesSubplot:xlabel='index', ylabel='sentiment_value'>

# %%
sent_df.plot.scatter(x='word_count', y='sentiment_value', figsize=(10,8), title='SENTENCE SENTIMENT VALUE TO SENTENCE WORD COUNT')
# Out:
# <AxesSubplot:title={'center':'SENTENCE SENTIMENT VALUE TO SENTENCE WORD COUNT'}, xlabel='word_count', ylabel='sentiment_value'>
